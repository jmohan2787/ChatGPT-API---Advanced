# %%
import openai

# %%
print(openai.__version__)
# Out:
# 2.14.0

# %%
from dotenv import load_dotenv
import os

load_dotenv()  # loads .env file

api_key = os.getenv("OPENAI_API_KEY")
if api_key:
    print('True')
else:
    print('False')
# Out:
# True

# %%
client = openai.OpenAI(api_key=api_key)

# %%
completion = client.chat.completions.create(model="gpt-3.5-turbo",
                                          messages=[{"role": "user",
                                                     "content": "Give me 3 ideas for apps I could build with openai apis "}])
print(completion.choices[0].message.content)
# Out:
# 1. A personal assistant app that utilizes OpenAI's text generation capabilities to help users draft emails, messages, and documents more efficiently. The app could suggest wording, structure, and tone based on the intended recipient and purpose of the communication.
#
# 2. A language translation app that leverages OpenAI's natural language processing to provide more accurate and nuanced translations between multiple languages. The app could also offer real-time speech translation for conversations or presentations.
#
# 3. A recommendation engine app that uses OpenAI's machine learning algorithms to curate personalized recommendations for books, movies, music, restaurants, and other products based on a user's preferences, behavior, and feedback. The app could continuously learn and adapt to provide more tailored recommendations over time.
